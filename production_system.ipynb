# %% [markdown]
# # Production System Assignment

# %%
from __future__ import annotations

import random
import statistics
from collections.abc import Callable, Sequence

import numpy as np
import simpy
from scipy import stats
from simpy.events import ProcessGenerator
from lib.server import Server
from lib.job import Job

# %%
class System:
    def __init__(
        self,
        env: simpy.Environment,
        inter_arrival_time_distribution: Callable[[], float],
        processing_time_per_family_distribution: list[Callable[[], float]],
        families_distribution: Callable[[], float],
        due_dates_distribution: Callable[[], float],
        routing_distribution: dict[int, list[Callable[[], float]]],
        routing_prob: dict[int, list[float]]
    ) -> None:
        self.env = env
        self.inter_arrival_time_distribution = inter_arrival_time_distribution
        self.processing_time_per_family_distribution = processing_time_per_family_distribution
        self.families_distribution = families_distribution
        self.due_dates_distribution = due_dates_distribution
        self.routing_distribution = routing_distribution
        self.routing_prob = routing_prob

        self.machines: list[Server] = []
        for i in range(6):
            server = Server(self.env, 1, "WC{}".format(i+1))
            self.machines.append(server)

        self.jobs: list[Job] = []
        self.env.process(self.run())

    @property
    def finished_jobs(self) -> int:
        return sum(job.done for job in self.jobs)

    def run(self) -> ProcessGenerator:
        idx = 0
        while True:
            timeout_inter_arrival = self.inter_arrival_time_distribution()
            weight = self.families_distribution()
            if weight <= 0.1:
                family = 1
            elif weight <= 0.62:
                family = 2
            else:
                family = 3
            processing_time = self.processing_time_per_family_distribution[family-1]()

            family_routing_distr = self.routing_distribution[family]
            family_routing_prob = self.routing_prob[family]

            job_routing = []
            for i in range(6):
                if family_routing_distr[i]() <= family_routing_prob[i]:
                    job_routing.append(self.machines[i])

            yield self.env.timeout(timeout_inter_arrival)

            job = Job(
                env=self.env,
                routing=job_routing,
                arrival_time=self.env.now,
                process_time=processing_time,
                idx=idx,
                family="F{}".format(family)
            )

            idx += 1
            self.jobs.append(job)
            self.env.process(job.main())

# %%
def run(seed: int | None) -> System:
    random.seed(seed)
    production_system = System(
        env=simpy.Environment(),
        inter_arrival_time_distribution=lambda: random.expovariate(lambd=0.65),
        processing_time_per_family_distribution=[
            lambda: random.gammavariate(2,2),
            lambda: random.gammavariate(4,0.5),
            lambda: random.gammavariate(6,1/6)
        ],
        families_distribution=lambda: random.random(),
        routing_distribution={
            1: [lambda: random.random(), lambda: random.random(), lambda: random.random(),lambda: random.random(),lambda: random.random(),lambda: random.random()],
            2: [lambda: random.random(), lambda: random.random(), lambda: random.random(),lambda: random.random(),lambda: random.random(),lambda: random.random()],
            3: [lambda: random.random(), lambda: random.random(), lambda: random.random(),lambda: random.random(),lambda: random.random(),lambda: random.random()]
        },
        routing_prob={
            1: [1,1,0,1,1,1],
            2: [0.8, 0.8, 1, 0.8, 0.8, 0.75],
            3: [0,0,1,0,0,0.75]
        },
        due_dates_distribution=lambda: random.uniform(30,50)
    )
    production_system.env.run(until=60*120)
    return production_system

# %%
manufacturing_system = run(seed=42)
# Out:
# PRODUCT 0 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 0 of family F1: Machine WC1 ready
# PRODUCT 0 of family F1: starting to be processed by the machine WC1
# PRODUCT 1 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 0 of family F1: Machine WC1 process finished
# PRODUCT 0 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 0 of family F1: Machine WC2 ready
# PRODUCT 0 of family F1: starting to be processed by the machine WC2
# PRODUCT 1 of family F2: Machine WC1 ready
# PRODUCT 1 of family F2: starting to be processed by the machine WC1
# PRODUCT 1 of family F2: Machine WC1 process finished
# PRODUCT 1 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 2 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2 of family F3: Machine WC3 ready
# PRODUCT 2 of family F3: starting to be processed by the machine WC3
# PRODUCT 2 of family F3: Machine WC3 process finished
# PRODUCT 2 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 2 of family F3: Machine WC6 ready
# PRODUCT 2 of family F3: starting to be processed by the machine WC6
# PRODUCT 2 of family F3: Machine WC6 process finished
# PRODUCT 0 of family F1: Machine WC2 process finished
# PRODUCT 0 of family F1: Waiting for the machine WC4 to become available
# PRODUCT 0 of family F1: Machine WC4 ready
# PRODUCT 0 of family F1: starting to be processed by the machine WC4
# PRODUCT 1 of family F2: Machine WC2 ready
# PRODUCT 1 of family F2: starting to be processed by the machine WC2
# PRODUCT 1 of family F2: Machine WC2 process finished
# PRODUCT 1 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 1 of family F2: Machine WC3 ready
# PRODUCT 1 of family F2: starting to be processed by the machine WC3
# PRODUCT 3 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 1 of family F2: Machine WC3 process finished
# PRODUCT 1 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 3 of family F3: Machine WC3 ready
# PRODUCT 3 of family F3: starting to be processed by the machine WC3
# PRODUCT 3 of family F3: Machine WC3 process finished
# PRODUCT 3 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 3 of family F3: Machine WC6 ready
# PRODUCT 3 of family F3: starting to be processed by the machine WC6
# PRODUCT 0 of family F1: Machine WC4 process finished
# PRODUCT 0 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 0 of family F1: Machine WC5 ready
# PRODUCT 0 of family F1: starting to be processed by the machine WC5
# PRODUCT 1 of family F2: Machine WC4 ready
# PRODUCT 1 of family F2: starting to be processed by the machine WC4
# PRODUCT 4 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 4 of family F1: Machine WC1 ready
# PRODUCT 4 of family F1: starting to be processed by the machine WC1
# PRODUCT 1 of family F2: Machine WC4 process finished
# PRODUCT 1 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 3 of family F3: Machine WC6 process finished
# PRODUCT 1 of family F2: Machine WC6 ready
# PRODUCT 1 of family F2: starting to be processed by the machine WC6
# PRODUCT 5 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 1 of family F2: Machine WC6 process finished
# PRODUCT 0 of family F1: Machine WC5 process finished
# PRODUCT 0 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 0 of family F1: Machine WC6 ready
# PRODUCT 0 of family F1: starting to be processed by the machine WC6
# PRODUCT 4 of family F1: Machine WC1 process finished
# PRODUCT 4 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 4 of family F1: Machine WC2 ready
# PRODUCT 4 of family F1: starting to be processed by the machine WC2
# PRODUCT 5 of family F2: Machine WC1 ready
# PRODUCT 5 of family F2: starting to be processed by the machine WC1
# PRODUCT 5 of family F2: Machine WC1 process finished
# PRODUCT 5 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 4 of family F1: Machine WC2 process finished
# PRODUCT 4 of family F1: Waiting for the machine WC4 to become available
# PRODUCT 4 of family F1: Machine WC4 ready
# PRODUCT 4 of family F1: starting to be processed by the machine WC4
# PRODUCT 5 of family F2: Machine WC2 ready
# PRODUCT 5 of family F2: starting to be processed by the machine WC2
# PRODUCT 0 of family F1: Machine WC6 process finished
# PRODUCT 5 of family F2: Machine WC2 process finished
# PRODUCT 5 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 5 of family F2: Machine WC3 ready
# PRODUCT 5 of family F2: starting to be processed by the machine WC3
# PRODUCT 4 of family F1: Machine WC4 process finished
# PRODUCT 4 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 4 of family F1: Machine WC5 ready
# PRODUCT 4 of family F1: starting to be processed by the machine WC5
# PRODUCT 5 of family F2: Machine WC3 process finished
# PRODUCT 5 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 5 of family F2: Machine WC4 ready
# PRODUCT 5 of family F2: starting to be processed by the machine WC4
# PRODUCT 6 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 6 of family F3: Machine WC3 ready
# PRODUCT 6 of family F3: starting to be processed by the machine WC3
# PRODUCT 4 of family F1: Machine WC5 process finished
# PRODUCT 4 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 4 of family F1: Machine WC6 ready
# PRODUCT 4 of family F1: starting to be processed by the machine WC6
# PRODUCT 5 of family F2: Machine WC4 process finished
# PRODUCT 5 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 5 of family F2: Machine WC5 ready
# PRODUCT 5 of family F2: starting to be processed by the machine WC5
# PRODUCT 7 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 6 of family F3: Machine WC3 process finished
# PRODUCT 6 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 7 of family F3: Machine WC3 ready
# PRODUCT 7 of family F3: starting to be processed by the machine WC3
# PRODUCT 5 of family F2: Machine WC5 process finished
# PRODUCT 5 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 8 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 4 of family F1: Machine WC6 process finished
# PRODUCT 6 of family F3: Machine WC6 ready
# PRODUCT 6 of family F3: starting to be processed by the machine WC6
# PRODUCT 7 of family F3: Machine WC3 process finished
# PRODUCT 7 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 8 of family F3: Machine WC3 ready
# PRODUCT 8 of family F3: starting to be processed by the machine WC3
# PRODUCT 8 of family F3: Machine WC3 process finished
# PRODUCT 8 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 6 of family F3: Machine WC6 process finished
# PRODUCT 5 of family F2: Machine WC6 ready
# PRODUCT 5 of family F2: starting to be processed by the machine WC6
# PRODUCT 9 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 9 of family F2: Machine WC2 ready
# PRODUCT 9 of family F2: starting to be processed by the machine WC2
# PRODUCT 5 of family F2: Machine WC6 process finished
# PRODUCT 7 of family F3: Machine WC6 ready
# PRODUCT 7 of family F3: starting to be processed by the machine WC6
# PRODUCT 9 of family F2: Machine WC2 process finished
# PRODUCT 9 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 9 of family F2: Machine WC3 ready
# PRODUCT 9 of family F2: starting to be processed by the machine WC3
# PRODUCT 9 of family F2: Machine WC3 process finished
# PRODUCT 9 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 9 of family F2: Machine WC5 ready
# PRODUCT 9 of family F2: starting to be processed by the machine WC5
# PRODUCT 7 of family F3: Machine WC6 process finished
# PRODUCT 8 of family F3: Machine WC6 ready
# PRODUCT 8 of family F3: starting to be processed by the machine WC6
# PRODUCT 10 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 10 of family F2: Machine WC1 ready
# PRODUCT 10 of family F2: starting to be processed by the machine WC1
# PRODUCT 9 of family F2: Machine WC5 process finished
# PRODUCT 9 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 8 of family F3: Machine WC6 process finished
# PRODUCT 9 of family F2: Machine WC6 ready
# PRODUCT 9 of family F2: starting to be processed by the machine WC6
# PRODUCT 11 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 10 of family F2: Machine WC1 process finished
# PRODUCT 10 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 10 of family F2: Machine WC2 ready
# PRODUCT 10 of family F2: starting to be processed by the machine WC2
# PRODUCT 11 of family F2: Machine WC1 ready
# PRODUCT 11 of family F2: starting to be processed by the machine WC1
# PRODUCT 9 of family F2: Machine WC6 process finished
# PRODUCT 10 of family F2: Machine WC2 process finished
# PRODUCT 10 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 10 of family F2: Machine WC3 ready
# PRODUCT 10 of family F2: starting to be processed by the machine WC3
# PRODUCT 12 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 13 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 10 of family F2: Machine WC3 process finished
# PRODUCT 10 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 10 of family F2: Machine WC6 ready
# PRODUCT 10 of family F2: starting to be processed by the machine WC6
# PRODUCT 12 of family F2: Machine WC3 ready
# PRODUCT 12 of family F2: starting to be processed by the machine WC3
# PRODUCT 14 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 12 of family F2: Machine WC3 process finished
# PRODUCT 12 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 12 of family F2: Machine WC4 ready
# PRODUCT 12 of family F2: starting to be processed by the machine WC4
# PRODUCT 15 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 12 of family F2: Machine WC4 process finished
# PRODUCT 10 of family F2: Machine WC6 process finished
# PRODUCT 11 of family F2: Machine WC1 process finished
# PRODUCT 11 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 11 of family F2: Machine WC2 ready
# PRODUCT 11 of family F2: starting to be processed by the machine WC2
# PRODUCT 13 of family F2: Machine WC1 ready
# PRODUCT 13 of family F2: starting to be processed by the machine WC1
# PRODUCT 13 of family F2: Machine WC1 process finished
# PRODUCT 13 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 14 of family F2: Machine WC1 ready
# PRODUCT 14 of family F2: starting to be processed by the machine WC1
# PRODUCT 16 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 14 of family F2: Machine WC1 process finished
# PRODUCT 14 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 15 of family F2: Machine WC1 ready
# PRODUCT 15 of family F2: starting to be processed by the machine WC1
# PRODUCT 17 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 15 of family F2: Machine WC1 process finished
# PRODUCT 15 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 16 of family F1: Machine WC1 ready
# PRODUCT 16 of family F1: starting to be processed by the machine WC1
# PRODUCT 18 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 11 of family F2: Machine WC2 process finished
# PRODUCT 11 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 11 of family F2: Machine WC3 ready
# PRODUCT 11 of family F2: starting to be processed by the machine WC3
# PRODUCT 13 of family F2: Machine WC2 ready
# PRODUCT 13 of family F2: starting to be processed by the machine WC2
# PRODUCT 13 of family F2: Machine WC2 process finished
# PRODUCT 13 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 14 of family F2: Machine WC2 ready
# PRODUCT 14 of family F2: starting to be processed by the machine WC2
# PRODUCT 19 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 16 of family F1: Machine WC1 process finished
# PRODUCT 16 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 17 of family F2: Machine WC1 ready
# PRODUCT 17 of family F2: starting to be processed by the machine WC1
# PRODUCT 20 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 17 of family F2: Machine WC1 process finished
# PRODUCT 17 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 18 of family F2: Machine WC1 ready
# PRODUCT 18 of family F2: starting to be processed by the machine WC1
# PRODUCT 14 of family F2: Machine WC2 process finished
# PRODUCT 14 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 15 of family F2: Machine WC2 ready
# PRODUCT 15 of family F2: starting to be processed by the machine WC2
# PRODUCT 21 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 18 of family F2: Machine WC1 process finished
# PRODUCT 18 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 19 of family F1: Machine WC1 ready
# PRODUCT 19 of family F1: starting to be processed by the machine WC1
# PRODUCT 15 of family F2: Machine WC2 process finished
# PRODUCT 15 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 16 of family F1: Machine WC2 ready
# PRODUCT 16 of family F1: starting to be processed by the machine WC2
# PRODUCT 22 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 11 of family F2: Machine WC3 process finished
# PRODUCT 11 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 11 of family F2: Machine WC4 ready
# PRODUCT 11 of family F2: starting to be processed by the machine WC4
# PRODUCT 13 of family F2: Machine WC3 ready
# PRODUCT 13 of family F2: starting to be processed by the machine WC3
# PRODUCT 13 of family F2: Machine WC3 process finished
# PRODUCT 13 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 14 of family F2: Machine WC3 ready
# PRODUCT 14 of family F2: starting to be processed by the machine WC3
# PRODUCT 23 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 24 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 16 of family F1: Machine WC2 process finished
# PRODUCT 16 of family F1: Waiting for the machine WC4 to become available
# PRODUCT 17 of family F2: Machine WC2 ready
# PRODUCT 17 of family F2: starting to be processed by the machine WC2
# PRODUCT 17 of family F2: Machine WC2 process finished
# PRODUCT 17 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 18 of family F2: Machine WC2 ready
# PRODUCT 18 of family F2: starting to be processed by the machine WC2
# PRODUCT 19 of family F1: Machine WC1 process finished
# PRODUCT 19 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 20 of family F2: Machine WC1 ready
# PRODUCT 20 of family F2: starting to be processed by the machine WC1
# PRODUCT 14 of family F2: Machine WC3 process finished
# PRODUCT 14 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 21 of family F3: Machine WC3 ready
# PRODUCT 21 of family F3: starting to be processed by the machine WC3
# PRODUCT 21 of family F3: Machine WC3 process finished
# PRODUCT 21 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 21 of family F3: Machine WC6 ready
# PRODUCT 21 of family F3: starting to be processed by the machine WC6
# PRODUCT 15 of family F2: Machine WC3 ready
# PRODUCT 15 of family F2: starting to be processed by the machine WC3
# PRODUCT 18 of family F2: Machine WC2 process finished
# PRODUCT 18 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 19 of family F1: Machine WC2 ready
# PRODUCT 19 of family F1: starting to be processed by the machine WC2
# PRODUCT 21 of family F3: Machine WC6 process finished
# PRODUCT 25 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 26 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 15 of family F2: Machine WC3 process finished
# PRODUCT 15 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 22 of family F3: Machine WC3 ready
# PRODUCT 22 of family F3: starting to be processed by the machine WC3
# PRODUCT 11 of family F2: Machine WC4 process finished
# PRODUCT 11 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 11 of family F2: Machine WC5 ready
# PRODUCT 11 of family F2: starting to be processed by the machine WC5
# PRODUCT 13 of family F2: Machine WC4 ready
# PRODUCT 13 of family F2: starting to be processed by the machine WC4
# PRODUCT 27 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 22 of family F3: Machine WC3 process finished
# PRODUCT 22 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 22 of family F3: Machine WC6 ready
# PRODUCT 22 of family F3: starting to be processed by the machine WC6
# PRODUCT 23 of family F3: Machine WC3 ready
# PRODUCT 23 of family F3: starting to be processed by the machine WC3
# PRODUCT 13 of family F2: Machine WC4 process finished
# PRODUCT 13 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 16 of family F1: Machine WC4 ready
# PRODUCT 16 of family F1: starting to be processed by the machine WC4
# PRODUCT 28 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 23 of family F3: Machine WC3 process finished
# PRODUCT 17 of family F2: Machine WC3 ready
# PRODUCT 17 of family F2: starting to be processed by the machine WC3
# PRODUCT 22 of family F3: Machine WC6 process finished
# PRODUCT 29 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 17 of family F2: Machine WC3 process finished
# PRODUCT 17 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 18 of family F2: Machine WC3 ready
# PRODUCT 18 of family F2: starting to be processed by the machine WC3
# PRODUCT 30 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 19 of family F1: Machine WC2 process finished
# PRODUCT 19 of family F1: Waiting for the machine WC4 to become available
# PRODUCT 16 of family F1: Machine WC4 process finished
# PRODUCT 16 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 14 of family F2: Machine WC4 ready
# PRODUCT 14 of family F2: starting to be processed by the machine WC4
# PRODUCT 31 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 18 of family F2: Machine WC3 process finished
# PRODUCT 18 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 25 of family F3: Machine WC3 ready
# PRODUCT 25 of family F3: starting to be processed by the machine WC3
# PRODUCT 32 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 20 of family F2: Machine WC1 process finished
# PRODUCT 20 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 20 of family F2: Machine WC2 ready
# PRODUCT 20 of family F2: starting to be processed by the machine WC2
# PRODUCT 24 of family F2: Machine WC1 ready
# PRODUCT 24 of family F2: starting to be processed by the machine WC1
# PRODUCT 25 of family F3: Machine WC3 process finished
# PRODUCT 27 of family F3: Machine WC3 ready
# PRODUCT 27 of family F3: starting to be processed by the machine WC3
# PRODUCT 11 of family F2: Machine WC5 process finished
# PRODUCT 11 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 11 of family F2: Machine WC6 ready
# PRODUCT 11 of family F2: starting to be processed by the machine WC6
# PRODUCT 13 of family F2: Machine WC5 ready
# PRODUCT 13 of family F2: starting to be processed by the machine WC5
# PRODUCT 14 of family F2: Machine WC4 process finished
# PRODUCT 14 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 15 of family F2: Machine WC4 ready
# PRODUCT 15 of family F2: starting to be processed by the machine WC4
# PRODUCT 24 of family F2: Machine WC1 process finished
# PRODUCT 24 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 26 of family F2: Machine WC1 ready
# PRODUCT 26 of family F2: starting to be processed by the machine WC1
# PRODUCT 27 of family F3: Machine WC3 process finished
# PRODUCT 27 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 29 of family F3: Machine WC3 ready
# PRODUCT 29 of family F3: starting to be processed by the machine WC3
# PRODUCT 13 of family F2: Machine WC5 process finished
# PRODUCT 16 of family F1: Machine WC5 ready
# PRODUCT 16 of family F1: starting to be processed by the machine WC5
# PRODUCT 26 of family F2: Machine WC1 process finished
# PRODUCT 26 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 28 of family F1: Machine WC1 ready
# PRODUCT 28 of family F1: starting to be processed by the machine WC1
# PRODUCT 15 of family F2: Machine WC4 process finished
# PRODUCT 15 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 17 of family F2: Machine WC4 ready
# PRODUCT 17 of family F2: starting to be processed by the machine WC4
# PRODUCT 28 of family F1: Machine WC1 process finished
# PRODUCT 28 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 29 of family F3: Machine WC3 process finished
# PRODUCT 30 of family F3: Machine WC3 ready
# PRODUCT 30 of family F3: starting to be processed by the machine WC3
# PRODUCT 17 of family F2: Machine WC4 process finished
# PRODUCT 17 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 19 of family F1: Machine WC4 ready
# PRODUCT 19 of family F1: starting to be processed by the machine WC4
# PRODUCT 30 of family F3: Machine WC3 process finished
# PRODUCT 30 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 31 of family F3: Machine WC3 ready
# PRODUCT 31 of family F3: starting to be processed by the machine WC3
# PRODUCT 16 of family F1: Machine WC5 process finished
# PRODUCT 16 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 18 of family F2: Machine WC5 ready
# PRODUCT 18 of family F2: starting to be processed by the machine WC5
# PRODUCT 33 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 18 of family F2: Machine WC5 process finished
# PRODUCT 14 of family F2: Machine WC5 ready
# PRODUCT 14 of family F2: starting to be processed by the machine WC5
# PRODUCT 31 of family F3: Machine WC3 process finished
# PRODUCT 32 of family F3: Machine WC3 ready
# PRODUCT 32 of family F3: starting to be processed by the machine WC3
# PRODUCT 11 of family F2: Machine WC6 process finished
# PRODUCT 27 of family F3: Machine WC6 ready
# PRODUCT 27 of family F3: starting to be processed by the machine WC6
# PRODUCT 32 of family F3: Machine WC3 process finished
# PRODUCT 24 of family F2: Machine WC3 ready
# PRODUCT 24 of family F2: starting to be processed by the machine WC3
# PRODUCT 27 of family F3: Machine WC6 process finished
# PRODUCT 17 of family F2: Machine WC6 ready
# PRODUCT 17 of family F2: starting to be processed by the machine WC6
# PRODUCT 20 of family F2: Machine WC2 process finished
# PRODUCT 20 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 26 of family F2: Machine WC2 ready
# PRODUCT 26 of family F2: starting to be processed by the machine WC2
# PRODUCT 24 of family F2: Machine WC3 process finished
# PRODUCT 24 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 20 of family F2: Machine WC3 ready
# PRODUCT 20 of family F2: starting to be processed by the machine WC3
# PRODUCT 14 of family F2: Machine WC5 process finished
# PRODUCT 14 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 15 of family F2: Machine WC5 ready
# PRODUCT 15 of family F2: starting to be processed by the machine WC5
# PRODUCT 19 of family F1: Machine WC4 process finished
# PRODUCT 19 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 17 of family F2: Machine WC6 process finished
# PRODUCT 30 of family F3: Machine WC6 ready
# PRODUCT 30 of family F3: starting to be processed by the machine WC6
# PRODUCT 26 of family F2: Machine WC2 process finished
# PRODUCT 26 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 28 of family F1: Machine WC2 ready
# PRODUCT 28 of family F1: starting to be processed by the machine WC2
# PRODUCT 30 of family F3: Machine WC6 process finished
# PRODUCT 16 of family F1: Machine WC6 ready
# PRODUCT 16 of family F1: starting to be processed by the machine WC6
# PRODUCT 15 of family F2: Machine WC5 process finished
# PRODUCT 24 of family F2: Machine WC5 ready
# PRODUCT 24 of family F2: starting to be processed by the machine WC5
# PRODUCT 28 of family F1: Machine WC2 process finished
# PRODUCT 28 of family F1: Waiting for the machine WC4 to become available
# PRODUCT 28 of family F1: Machine WC4 ready
# PRODUCT 28 of family F1: starting to be processed by the machine WC4
# PRODUCT 33 of family F2: Machine WC2 ready
# PRODUCT 33 of family F2: starting to be processed by the machine WC2
# PRODUCT 24 of family F2: Machine WC5 process finished
# PRODUCT 24 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 19 of family F1: Machine WC5 ready
# PRODUCT 19 of family F1: starting to be processed by the machine WC5
# PRODUCT 28 of family F1: Machine WC4 process finished
# PRODUCT 28 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 34 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 34 of family F2: Machine WC1 ready
# PRODUCT 34 of family F2: starting to be processed by the machine WC1
# PRODUCT 16 of family F1: Machine WC6 process finished
# PRODUCT 14 of family F2: Machine WC6 ready
# PRODUCT 14 of family F2: starting to be processed by the machine WC6
# PRODUCT 35 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 34 of family F2: Machine WC1 process finished
# PRODUCT 34 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 33 of family F2: Machine WC2 process finished
# PRODUCT 33 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 34 of family F2: Machine WC2 ready
# PRODUCT 34 of family F2: starting to be processed by the machine WC2
# PRODUCT 36 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 36 of family F2: Machine WC1 ready
# PRODUCT 36 of family F2: starting to be processed by the machine WC1
# PRODUCT 34 of family F2: Machine WC2 process finished
# PRODUCT 34 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 37 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 14 of family F2: Machine WC6 process finished
# PRODUCT 24 of family F2: Machine WC6 ready
# PRODUCT 24 of family F2: starting to be processed by the machine WC6
# PRODUCT 24 of family F2: Machine WC6 process finished
# PRODUCT 19 of family F1: Machine WC5 process finished
# PRODUCT 19 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 19 of family F1: Machine WC6 ready
# PRODUCT 19 of family F1: starting to be processed by the machine WC6
# PRODUCT 28 of family F1: Machine WC5 ready
# PRODUCT 28 of family F1: starting to be processed by the machine WC5
# PRODUCT 20 of family F2: Machine WC3 process finished
# PRODUCT 20 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 20 of family F2: Machine WC4 ready
# PRODUCT 20 of family F2: starting to be processed by the machine WC4
# PRODUCT 26 of family F2: Machine WC3 ready
# PRODUCT 26 of family F2: starting to be processed by the machine WC3
# PRODUCT 36 of family F2: Machine WC1 process finished
# PRODUCT 36 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 36 of family F2: Machine WC2 ready
# PRODUCT 36 of family F2: starting to be processed by the machine WC2
# PRODUCT 37 of family F2: Machine WC1 ready
# PRODUCT 37 of family F2: starting to be processed by the machine WC1
# PRODUCT 38 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 28 of family F1: Machine WC5 process finished
# PRODUCT 28 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 26 of family F2: Machine WC3 process finished
# PRODUCT 26 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 35 of family F3: Machine WC3 ready
# PRODUCT 35 of family F3: starting to be processed by the machine WC3
# PRODUCT 35 of family F3: Machine WC3 process finished
# PRODUCT 35 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 33 of family F2: Machine WC3 ready
# PRODUCT 33 of family F2: starting to be processed by the machine WC3
# PRODUCT 36 of family F2: Machine WC2 process finished
# PRODUCT 36 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 39 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 33 of family F2: Machine WC3 process finished
# PRODUCT 33 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 34 of family F2: Machine WC3 ready
# PRODUCT 34 of family F2: starting to be processed by the machine WC3
# PRODUCT 19 of family F1: Machine WC6 process finished
# PRODUCT 28 of family F1: Machine WC6 ready
# PRODUCT 28 of family F1: starting to be processed by the machine WC6
# PRODUCT 34 of family F2: Machine WC3 process finished
# PRODUCT 34 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 36 of family F2: Machine WC3 ready
# PRODUCT 36 of family F2: starting to be processed by the machine WC3
# PRODUCT 28 of family F1: Machine WC6 process finished
# PRODUCT 35 of family F3: Machine WC6 ready
# PRODUCT 35 of family F3: starting to be processed by the machine WC6
# PRODUCT 37 of family F2: Machine WC1 process finished
# PRODUCT 37 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 37 of family F2: Machine WC2 ready
# PRODUCT 37 of family F2: starting to be processed by the machine WC2
# PRODUCT 38 of family F2: Machine WC1 ready
# PRODUCT 38 of family F2: starting to be processed by the machine WC1
# PRODUCT 35 of family F3: Machine WC6 process finished
# PRODUCT 40 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 36 of family F2: Machine WC3 process finished
# PRODUCT 36 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 20 of family F2: Machine WC4 process finished
# PRODUCT 20 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 20 of family F2: Machine WC6 ready
# PRODUCT 20 of family F2: starting to be processed by the machine WC6
# PRODUCT 26 of family F2: Machine WC4 ready
# PRODUCT 26 of family F2: starting to be processed by the machine WC4
# PRODUCT 38 of family F2: Machine WC1 process finished
# PRODUCT 38 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 38 of family F2: Machine WC3 ready
# PRODUCT 38 of family F2: starting to be processed by the machine WC3
# PRODUCT 39 of family F2: Machine WC1 ready
# PRODUCT 39 of family F2: starting to be processed by the machine WC1
# PRODUCT 41 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 26 of family F2: Machine WC4 process finished
# PRODUCT 26 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 26 of family F2: Machine WC5 ready
# PRODUCT 26 of family F2: starting to be processed by the machine WC5
# PRODUCT 33 of family F2: Machine WC4 ready
# PRODUCT 33 of family F2: starting to be processed by the machine WC4
# PRODUCT 42 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 26 of family F2: Machine WC5 process finished
# PRODUCT 26 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 38 of family F2: Machine WC3 process finished
# PRODUCT 38 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 41 of family F3: Machine WC3 ready
# PRODUCT 41 of family F3: starting to be processed by the machine WC3
# PRODUCT 41 of family F3: Machine WC3 process finished
# PRODUCT 42 of family F3: Machine WC3 ready
# PRODUCT 42 of family F3: starting to be processed by the machine WC3
# PRODUCT 37 of family F2: Machine WC2 process finished
# PRODUCT 37 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 33 of family F2: Machine WC4 process finished
# PRODUCT 33 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 34 of family F2: Machine WC4 ready
# PRODUCT 34 of family F2: starting to be processed by the machine WC4
# PRODUCT 39 of family F2: Machine WC1 process finished
# PRODUCT 39 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 39 of family F2: Machine WC2 ready
# PRODUCT 39 of family F2: starting to be processed by the machine WC2
# PRODUCT 40 of family F1: Machine WC1 ready
# PRODUCT 40 of family F1: starting to be processed by the machine WC1
# PRODUCT 42 of family F3: Machine WC3 process finished
# PRODUCT 42 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 37 of family F2: Machine WC3 ready
# PRODUCT 37 of family F2: starting to be processed by the machine WC3
# PRODUCT 43 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 34 of family F2: Machine WC4 process finished
# PRODUCT 34 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 34 of family F2: Machine WC5 ready
# PRODUCT 34 of family F2: starting to be processed by the machine WC5
# PRODUCT 36 of family F2: Machine WC4 ready
# PRODUCT 36 of family F2: starting to be processed by the machine WC4
# PRODUCT 34 of family F2: Machine WC5 process finished
# PRODUCT 34 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 44 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 36 of family F2: Machine WC4 process finished
# PRODUCT 36 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 36 of family F2: Machine WC5 ready
# PRODUCT 36 of family F2: starting to be processed by the machine WC5
# PRODUCT 38 of family F2: Machine WC4 ready
# PRODUCT 38 of family F2: starting to be processed by the machine WC4
# PRODUCT 20 of family F2: Machine WC6 process finished
# PRODUCT 26 of family F2: Machine WC6 ready
# PRODUCT 26 of family F2: starting to be processed by the machine WC6
# PRODUCT 40 of family F1: Machine WC1 process finished
# PRODUCT 40 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 43 of family F2: Machine WC1 ready
# PRODUCT 43 of family F2: starting to be processed by the machine WC1
# PRODUCT 39 of family F2: Machine WC2 process finished
# PRODUCT 39 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 40 of family F1: Machine WC2 ready
# PRODUCT 40 of family F1: starting to be processed by the machine WC2
# PRODUCT 36 of family F2: Machine WC5 process finished
# PRODUCT 36 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 26 of family F2: Machine WC6 process finished
# PRODUCT 33 of family F2: Machine WC6 ready
# PRODUCT 33 of family F2: starting to be processed by the machine WC6
# PRODUCT 45 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 38 of family F2: Machine WC4 process finished
# PRODUCT 38 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 38 of family F2: Machine WC5 ready
# PRODUCT 38 of family F2: starting to be processed by the machine WC5
# PRODUCT 37 of family F2: Machine WC3 process finished
# PRODUCT 37 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 37 of family F2: Machine WC4 ready
# PRODUCT 37 of family F2: starting to be processed by the machine WC4
# PRODUCT 39 of family F2: Machine WC3 ready
# PRODUCT 39 of family F2: starting to be processed by the machine WC3
# PRODUCT 38 of family F2: Machine WC5 process finished
# PRODUCT 38 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 33 of family F2: Machine WC6 process finished
# PRODUCT 42 of family F3: Machine WC6 ready
# PRODUCT 42 of family F3: starting to be processed by the machine WC6
# PRODUCT 40 of family F1: Machine WC2 process finished
# PRODUCT 40 of family F1: Waiting for the machine WC4 to become available
# PRODUCT 46 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 42 of family F3: Machine WC6 process finished
# PRODUCT 34 of family F2: Machine WC6 ready
# PRODUCT 34 of family F2: starting to be processed by the machine WC6
# PRODUCT 43 of family F2: Machine WC1 process finished
# PRODUCT 43 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 43 of family F2: Machine WC2 ready
# PRODUCT 43 of family F2: starting to be processed by the machine WC2
# PRODUCT 44 of family F2: Machine WC1 ready
# PRODUCT 44 of family F2: starting to be processed by the machine WC1
# PRODUCT 47 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 39 of family F2: Machine WC3 process finished
# PRODUCT 39 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 46 of family F3: Machine WC3 ready
# PRODUCT 46 of family F3: starting to be processed by the machine WC3
# PRODUCT 34 of family F2: Machine WC6 process finished
# PRODUCT 36 of family F2: Machine WC6 ready
# PRODUCT 36 of family F2: starting to be processed by the machine WC6
# PRODUCT 44 of family F2: Machine WC1 process finished
# PRODUCT 44 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 45 of family F1: Machine WC1 ready
# PRODUCT 45 of family F1: starting to be processed by the machine WC1
# PRODUCT 46 of family F3: Machine WC3 process finished
# PRODUCT 46 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 48 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 49 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 50 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 37 of family F2: Machine WC4 process finished
# PRODUCT 37 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 37 of family F2: Machine WC5 ready
# PRODUCT 37 of family F2: starting to be processed by the machine WC5
# PRODUCT 40 of family F1: Machine WC4 ready
# PRODUCT 40 of family F1: starting to be processed by the machine WC4
# PRODUCT 51 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 51 of family F3: Machine WC3 ready
# PRODUCT 51 of family F3: starting to be processed by the machine WC3
# PRODUCT 36 of family F2: Machine WC6 process finished
# PRODUCT 38 of family F2: Machine WC6 ready
# PRODUCT 38 of family F2: starting to be processed by the machine WC6
# PRODUCT 51 of family F3: Machine WC3 process finished
# PRODUCT 51 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 38 of family F2: Machine WC6 process finished
# PRODUCT 46 of family F3: Machine WC6 ready
# PRODUCT 46 of family F3: starting to be processed by the machine WC6
# PRODUCT 45 of family F1: Machine WC1 process finished
# PRODUCT 45 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 47 of family F2: Machine WC1 ready
# PRODUCT 47 of family F2: starting to be processed by the machine WC1
# PRODUCT 52 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 52 of family F3: Machine WC3 ready
# PRODUCT 52 of family F3: starting to be processed by the machine WC3
# PRODUCT 53 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 43 of family F2: Machine WC2 process finished
# PRODUCT 43 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 44 of family F2: Machine WC2 ready
# PRODUCT 44 of family F2: starting to be processed by the machine WC2
# PRODUCT 46 of family F3: Machine WC6 process finished
# PRODUCT 51 of family F3: Machine WC6 ready
# PRODUCT 51 of family F3: starting to be processed by the machine WC6
# PRODUCT 40 of family F1: Machine WC4 process finished
# PRODUCT 40 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 39 of family F2: Machine WC4 ready
# PRODUCT 39 of family F2: starting to be processed by the machine WC4
# PRODUCT 52 of family F3: Machine WC3 process finished
# PRODUCT 52 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 53 of family F3: Machine WC3 ready
# PRODUCT 53 of family F3: starting to be processed by the machine WC3
# PRODUCT 47 of family F2: Machine WC1 process finished
# PRODUCT 47 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 48 of family F2: Machine WC1 ready
# PRODUCT 48 of family F2: starting to be processed by the machine WC1
# PRODUCT 44 of family F2: Machine WC2 process finished
# PRODUCT 44 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 45 of family F1: Machine WC2 ready
# PRODUCT 45 of family F1: starting to be processed by the machine WC2
# PRODUCT 54 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 51 of family F3: Machine WC6 process finished
# PRODUCT 52 of family F3: Machine WC6 ready
# PRODUCT 52 of family F3: starting to be processed by the machine WC6
# PRODUCT 37 of family F2: Machine WC5 process finished
# PRODUCT 37 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 40 of family F1: Machine WC5 ready
# PRODUCT 40 of family F1: starting to be processed by the machine WC5
# PRODUCT 52 of family F3: Machine WC6 process finished
# PRODUCT 37 of family F2: Machine WC6 ready
# PRODUCT 37 of family F2: starting to be processed by the machine WC6
# PRODUCT 53 of family F3: Machine WC3 process finished
# PRODUCT 53 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 43 of family F2: Machine WC3 ready
# PRODUCT 43 of family F2: starting to be processed by the machine WC3
# PRODUCT 55 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 48 of family F2: Machine WC1 process finished
# PRODUCT 48 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 49 of family F2: Machine WC1 ready
# PRODUCT 49 of family F2: starting to be processed by the machine WC1
# PRODUCT 39 of family F2: Machine WC4 process finished
# PRODUCT 39 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 45 of family F1: Machine WC2 process finished
# PRODUCT 45 of family F1: Waiting for the machine WC4 to become available
# PRODUCT 45 of family F1: Machine WC4 ready
# PRODUCT 45 of family F1: starting to be processed by the machine WC4
# PRODUCT 47 of family F2: Machine WC2 ready
# PRODUCT 47 of family F2: starting to be processed by the machine WC2
# PRODUCT 49 of family F2: Machine WC1 process finished
# PRODUCT 49 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 50 of family F2: Machine WC1 ready
# PRODUCT 50 of family F2: starting to be processed by the machine WC1
# PRODUCT 40 of family F1: Machine WC5 process finished
# PRODUCT 40 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 39 of family F2: Machine WC5 ready
# PRODUCT 39 of family F2: starting to be processed by the machine WC5
# PRODUCT 47 of family F2: Machine WC2 process finished
# PRODUCT 47 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 48 of family F2: Machine WC2 ready
# PRODUCT 48 of family F2: starting to be processed by the machine WC2
# PRODUCT 56 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 57 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 37 of family F2: Machine WC6 process finished
# PRODUCT 53 of family F3: Machine WC6 ready
# PRODUCT 53 of family F3: starting to be processed by the machine WC6
# PRODUCT 43 of family F2: Machine WC3 process finished
# PRODUCT 43 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 44 of family F2: Machine WC3 ready
# PRODUCT 44 of family F2: starting to be processed by the machine WC3
# PRODUCT 50 of family F2: Machine WC1 process finished
# PRODUCT 50 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 54 of family F2: Machine WC1 ready
# PRODUCT 54 of family F2: starting to be processed by the machine WC1
# PRODUCT 45 of family F1: Machine WC4 process finished
# PRODUCT 45 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 43 of family F2: Machine WC4 ready
# PRODUCT 43 of family F2: starting to be processed by the machine WC4
# PRODUCT 44 of family F2: Machine WC3 process finished
# PRODUCT 44 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 55 of family F3: Machine WC3 ready
# PRODUCT 55 of family F3: starting to be processed by the machine WC3
# PRODUCT 48 of family F2: Machine WC2 process finished
# PRODUCT 48 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 49 of family F2: Machine WC2 ready
# PRODUCT 49 of family F2: starting to be processed by the machine WC2
# PRODUCT 58 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 55 of family F3: Machine WC3 process finished
# PRODUCT 47 of family F2: Machine WC3 ready
# PRODUCT 47 of family F2: starting to be processed by the machine WC3
# PRODUCT 39 of family F2: Machine WC5 process finished
# PRODUCT 39 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 45 of family F1: Machine WC5 ready
# PRODUCT 45 of family F1: starting to be processed by the machine WC5
# PRODUCT 53 of family F3: Machine WC6 process finished
# PRODUCT 40 of family F1: Machine WC6 ready
# PRODUCT 40 of family F1: starting to be processed by the machine WC6
# PRODUCT 49 of family F2: Machine WC2 process finished
# PRODUCT 49 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 50 of family F2: Machine WC2 ready
# PRODUCT 50 of family F2: starting to be processed by the machine WC2
# PRODUCT 59 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 47 of family F2: Machine WC3 process finished
# PRODUCT 47 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 57 of family F3: Machine WC3 ready
# PRODUCT 57 of family F3: starting to be processed by the machine WC3
# PRODUCT 60 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 54 of family F2: Machine WC1 process finished
# PRODUCT 54 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 56 of family F1: Machine WC1 ready
# PRODUCT 56 of family F1: starting to be processed by the machine WC1
# PRODUCT 57 of family F3: Machine WC3 process finished
# PRODUCT 48 of family F2: Machine WC3 ready
# PRODUCT 48 of family F2: starting to be processed by the machine WC3
# PRODUCT 61 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 50 of family F2: Machine WC2 process finished
# PRODUCT 50 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 61 of family F2: Machine WC2 ready
# PRODUCT 61 of family F2: starting to be processed by the machine WC2
# PRODUCT 45 of family F1: Machine WC5 process finished
# PRODUCT 45 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 40 of family F1: Machine WC6 process finished
# PRODUCT 39 of family F2: Machine WC6 ready
# PRODUCT 39 of family F2: starting to be processed by the machine WC6
# PRODUCT 43 of family F2: Machine WC4 process finished
# PRODUCT 43 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 43 of family F2: Machine WC5 ready
# PRODUCT 43 of family F2: starting to be processed by the machine WC5
# PRODUCT 44 of family F2: Machine WC4 ready
# PRODUCT 44 of family F2: starting to be processed by the machine WC4
# PRODUCT 44 of family F2: Machine WC4 process finished
# PRODUCT 44 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 47 of family F2: Machine WC4 ready
# PRODUCT 47 of family F2: starting to be processed by the machine WC4
# PRODUCT 48 of family F2: Machine WC3 process finished
# PRODUCT 48 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 58 of family F3: Machine WC3 ready
# PRODUCT 58 of family F3: starting to be processed by the machine WC3
# PRODUCT 61 of family F2: Machine WC2 process finished
# PRODUCT 61 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 47 of family F2: Machine WC4 process finished
# PRODUCT 47 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 48 of family F2: Machine WC4 ready
# PRODUCT 48 of family F2: starting to be processed by the machine WC4
# PRODUCT 62 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 63 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 58 of family F3: Machine WC3 process finished
# PRODUCT 58 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 49 of family F2: Machine WC3 ready
# PRODUCT 49 of family F2: starting to be processed by the machine WC3
# PRODUCT 56 of family F1: Machine WC1 process finished
# PRODUCT 56 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 56 of family F1: Machine WC2 ready
# PRODUCT 56 of family F1: starting to be processed by the machine WC2
# PRODUCT 59 of family F2: Machine WC1 ready
# ...
# PRODUCT 2805 of family F2: Machine WC1 process finished
# PRODUCT 2805 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 2808 of family F1: Machine WC1 ready
# PRODUCT 2808 of family F1: starting to be processed by the machine WC1
# PRODUCT 2814 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2787 of family F1: Machine WC4 process finished
# PRODUCT 2787 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 2787 of family F1: Machine WC5 ready
# PRODUCT 2787 of family F1: starting to be processed by the machine WC5
# PRODUCT 2734 of family F2: Machine WC4 ready
# PRODUCT 2734 of family F2: starting to be processed by the machine WC4
# PRODUCT 2815 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2797 of family F2: Machine WC2 process finished
# PRODUCT 2797 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2798 of family F2: Machine WC2 ready
# PRODUCT 2798 of family F2: starting to be processed by the machine WC2
# PRODUCT 2816 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 2720 of family F2: Machine WC6 process finished
# PRODUCT 2738 of family F3: Machine WC6 ready
# PRODUCT 2738 of family F3: starting to be processed by the machine WC6
# PRODUCT 2736 of family F2: Machine WC3 process finished
# PRODUCT 2736 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 2744 of family F2: Machine WC3 ready
# PRODUCT 2744 of family F2: starting to be processed by the machine WC3
# PRODUCT 2798 of family F2: Machine WC2 process finished
# PRODUCT 2798 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2799 of family F2: Machine WC2 ready
# PRODUCT 2799 of family F2: starting to be processed by the machine WC2
# PRODUCT 2738 of family F3: Machine WC6 process finished
# PRODUCT 2726 of family F2: Machine WC6 ready
# PRODUCT 2726 of family F2: starting to be processed by the machine WC6
# PRODUCT 2808 of family F1: Machine WC1 process finished
# PRODUCT 2808 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 2809 of family F2: Machine WC1 ready
# PRODUCT 2809 of family F2: starting to be processed by the machine WC1
# PRODUCT 2734 of family F2: Machine WC4 process finished
# PRODUCT 2734 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 2735 of family F2: Machine WC4 ready
# PRODUCT 2735 of family F2: starting to be processed by the machine WC4
# PRODUCT 2799 of family F2: Machine WC2 process finished
# PRODUCT 2799 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2801 of family F2: Machine WC2 ready
# PRODUCT 2801 of family F2: starting to be processed by the machine WC2
# PRODUCT 2809 of family F2: Machine WC1 process finished
# PRODUCT 2809 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2812 of family F1: Machine WC1 ready
# PRODUCT 2812 of family F1: starting to be processed by the machine WC1
# PRODUCT 2817 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2735 of family F2: Machine WC4 process finished
# PRODUCT 2735 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 2796 of family F1: Machine WC4 ready
# PRODUCT 2796 of family F1: starting to be processed by the machine WC4
# PRODUCT 2744 of family F2: Machine WC3 process finished
# PRODUCT 2744 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 2747 of family F3: Machine WC3 ready
# PRODUCT 2747 of family F3: starting to be processed by the machine WC3
# PRODUCT 2726 of family F2: Machine WC6 process finished
# PRODUCT 2731 of family F2: Machine WC6 ready
# PRODUCT 2731 of family F2: starting to be processed by the machine WC6
# PRODUCT 2818 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2801 of family F2: Machine WC2 process finished
# PRODUCT 2801 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2802 of family F2: Machine WC2 ready
# PRODUCT 2802 of family F2: starting to be processed by the machine WC2
# PRODUCT 2819 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2820 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2821 of family F1: Waiting for the machine WC1 to become available
# PRODUCT 2787 of family F1: Machine WC5 process finished
# PRODUCT 2787 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 2734 of family F2: Machine WC5 ready
# PRODUCT 2734 of family F2: starting to be processed by the machine WC5
# PRODUCT 2802 of family F2: Machine WC2 process finished
# PRODUCT 2802 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2805 of family F2: Machine WC2 ready
# PRODUCT 2805 of family F2: starting to be processed by the machine WC2
# PRODUCT 2747 of family F3: Machine WC3 process finished
# PRODUCT 2741 of family F2: Machine WC3 ready
# PRODUCT 2741 of family F2: starting to be processed by the machine WC3
# PRODUCT 2731 of family F2: Machine WC6 process finished
# PRODUCT 2787 of family F1: Machine WC6 ready
# PRODUCT 2787 of family F1: starting to be processed by the machine WC6
# PRODUCT 2796 of family F1: Machine WC4 process finished
# PRODUCT 2796 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 2739 of family F2: Machine WC4 ready
# PRODUCT 2739 of family F2: starting to be processed by the machine WC4
# PRODUCT 2805 of family F2: Machine WC2 process finished
# PRODUCT 2805 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2816 of family F2: Machine WC2 ready
# PRODUCT 2816 of family F2: starting to be processed by the machine WC2
# PRODUCT 2822 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2823 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2824 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2739 of family F2: Machine WC4 process finished
# PRODUCT 2739 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 2736 of family F2: Machine WC4 ready
# PRODUCT 2736 of family F2: starting to be processed by the machine WC4
# PRODUCT 2825 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2734 of family F2: Machine WC5 process finished
# PRODUCT 2735 of family F2: Machine WC5 ready
# PRODUCT 2735 of family F2: starting to be processed by the machine WC5
# PRODUCT 2826 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2827 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2828 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2735 of family F2: Machine WC5 process finished
# PRODUCT 2735 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 2744 of family F2: Machine WC5 ready
# PRODUCT 2744 of family F2: starting to be processed by the machine WC5
# PRODUCT 2829 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2741 of family F2: Machine WC3 process finished
# PRODUCT 2741 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 2737 of family F2: Machine WC3 ready
# PRODUCT 2737 of family F2: starting to be processed by the machine WC3
# PRODUCT 2816 of family F2: Machine WC2 process finished
# PRODUCT 2816 of family F2: Waiting for the machine WC3 to become available
# PRODUCT 2808 of family F1: Machine WC2 ready
# PRODUCT 2808 of family F1: starting to be processed by the machine WC2
# PRODUCT 2830 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2744 of family F2: Machine WC5 process finished
# PRODUCT 2744 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 2796 of family F1: Machine WC5 ready
# PRODUCT 2796 of family F1: starting to be processed by the machine WC5
# PRODUCT 2787 of family F1: Machine WC6 process finished
# PRODUCT 2735 of family F2: Machine WC6 ready
# PRODUCT 2735 of family F2: starting to be processed by the machine WC6
# PRODUCT 2737 of family F2: Machine WC3 process finished
# PRODUCT 2737 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 2749 of family F3: Machine WC3 ready
# PRODUCT 2749 of family F3: starting to be processed by the machine WC3
# PRODUCT 2831 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2736 of family F2: Machine WC4 process finished
# PRODUCT 2736 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 2741 of family F2: Machine WC4 ready
# PRODUCT 2741 of family F2: starting to be processed by the machine WC4
# PRODUCT 2735 of family F2: Machine WC6 process finished
# PRODUCT 2744 of family F2: Machine WC6 ready
# PRODUCT 2744 of family F2: starting to be processed by the machine WC6
# PRODUCT 2749 of family F3: Machine WC3 process finished
# PRODUCT 2749 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 2751 of family F2: Machine WC3 ready
# PRODUCT 2751 of family F2: starting to be processed by the machine WC3
# PRODUCT 2832 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2808 of family F1: Machine WC2 process finished
# PRODUCT 2808 of family F1: Waiting for the machine WC4 to become available
# PRODUCT 2744 of family F2: Machine WC6 process finished
# PRODUCT 2749 of family F3: Machine WC6 ready
# PRODUCT 2749 of family F3: starting to be processed by the machine WC6
# PRODUCT 2796 of family F1: Machine WC5 process finished
# PRODUCT 2796 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 2739 of family F2: Machine WC5 ready
# PRODUCT 2739 of family F2: starting to be processed by the machine WC5
# PRODUCT 2749 of family F3: Machine WC6 process finished
# PRODUCT 2796 of family F1: Machine WC6 ready
# PRODUCT 2796 of family F1: starting to be processed by the machine WC6
# PRODUCT 2751 of family F2: Machine WC3 process finished
# PRODUCT 2751 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 2757 of family F3: Machine WC3 ready
# PRODUCT 2757 of family F3: starting to be processed by the machine WC3
# PRODUCT 2812 of family F1: Machine WC1 process finished
# PRODUCT 2812 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 2812 of family F1: Machine WC2 ready
# PRODUCT 2812 of family F1: starting to be processed by the machine WC2
# PRODUCT 2813 of family F1: Machine WC1 ready
# PRODUCT 2813 of family F1: starting to be processed by the machine WC1
# PRODUCT 2741 of family F2: Machine WC4 process finished
# PRODUCT 2741 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 2737 of family F2: Machine WC4 ready
# PRODUCT 2737 of family F2: starting to be processed by the machine WC4
# PRODUCT 2757 of family F3: Machine WC3 process finished
# PRODUCT 2757 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 2743 of family F2: Machine WC3 ready
# PRODUCT 2743 of family F2: starting to be processed by the machine WC3
# PRODUCT 2739 of family F2: Machine WC5 process finished
# PRODUCT 2736 of family F2: Machine WC5 ready
# PRODUCT 2736 of family F2: starting to be processed by the machine WC5
# PRODUCT 2833 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2737 of family F2: Machine WC4 process finished
# PRODUCT 2737 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 2808 of family F1: Machine WC4 ready
# PRODUCT 2808 of family F1: starting to be processed by the machine WC4
# PRODUCT 2743 of family F2: Machine WC3 process finished
# PRODUCT 2743 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 2760 of family F3: Machine WC3 ready
# PRODUCT 2760 of family F3: starting to be processed by the machine WC3
# PRODUCT 2796 of family F1: Machine WC6 process finished
# PRODUCT 2741 of family F2: Machine WC6 ready
# PRODUCT 2741 of family F2: starting to be processed by the machine WC6
# PRODUCT 2760 of family F3: Machine WC3 process finished
# PRODUCT 2760 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 2761 of family F3: Machine WC3 ready
# PRODUCT 2761 of family F3: starting to be processed by the machine WC3
# PRODUCT 2834 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 2736 of family F2: Machine WC5 process finished
# PRODUCT 2736 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 2737 of family F2: Machine WC5 ready
# PRODUCT 2737 of family F2: starting to be processed by the machine WC5
# PRODUCT 2813 of family F1: Machine WC1 process finished
# PRODUCT 2813 of family F1: Waiting for the machine WC2 to become available
# PRODUCT 2814 of family F2: Machine WC1 ready
# PRODUCT 2814 of family F2: starting to be processed by the machine WC1
# PRODUCT 2761 of family F3: Machine WC3 process finished
# PRODUCT 2761 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 2762 of family F3: Machine WC3 ready
# PRODUCT 2762 of family F3: starting to be processed by the machine WC3
# PRODUCT 2835 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2808 of family F1: Machine WC4 process finished
# PRODUCT 2808 of family F1: Waiting for the machine WC5 to become available
# PRODUCT 2751 of family F2: Machine WC4 ready
# PRODUCT 2751 of family F2: starting to be processed by the machine WC4
# PRODUCT 2762 of family F3: Machine WC3 process finished
# PRODUCT 2762 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 2763 of family F3: Machine WC3 ready
# PRODUCT 2763 of family F3: starting to be processed by the machine WC3
# PRODUCT 2737 of family F2: Machine WC5 process finished
# PRODUCT 2737 of family F2: Waiting for the machine WC6 to become available
# PRODUCT 2808 of family F1: Machine WC5 ready
# PRODUCT 2808 of family F1: starting to be processed by the machine WC5
# PRODUCT 2741 of family F2: Machine WC6 process finished
# PRODUCT 2757 of family F3: Machine WC6 ready
# PRODUCT 2757 of family F3: starting to be processed by the machine WC6
# PRODUCT 2814 of family F2: Machine WC1 process finished
# PRODUCT 2814 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 2817 of family F2: Machine WC1 ready
# PRODUCT 2817 of family F2: starting to be processed by the machine WC1
# PRODUCT 2763 of family F3: Machine WC3 process finished
# PRODUCT 2763 of family F3: Waiting for the machine WC6 to become available
# PRODUCT 2758 of family F2: Machine WC3 ready
# PRODUCT 2758 of family F2: starting to be processed by the machine WC3
# PRODUCT 2757 of family F3: Machine WC6 process finished
# PRODUCT 2743 of family F2: Machine WC6 ready
# PRODUCT 2743 of family F2: starting to be processed by the machine WC6
# PRODUCT 2836 of family F3: Waiting for the machine WC3 to become available
# PRODUCT 2751 of family F2: Machine WC4 process finished
# PRODUCT 2751 of family F2: Waiting for the machine WC5 to become available
# PRODUCT 2817 of family F2: Machine WC1 process finished
# PRODUCT 2817 of family F2: Waiting for the machine WC2 to become available
# PRODUCT 2819 of family F2: Machine WC1 ready
# PRODUCT 2819 of family F2: starting to be processed by the machine WC1
# PRODUCT 2758 of family F2: Machine WC3 process finished
# PRODUCT 2758 of family F2: Waiting for the machine WC4 to become available
# PRODUCT 2758 of family F2: Machine WC4 ready
# PRODUCT 2758 of family F2: starting to be processed by the machine WC4
# PRODUCT 2745 of family F2: Machine WC3 ready
# PRODUCT 2745 of family F2: starting to be processed by the machine WC3
# PRODUCT 2808 of family F1: Machine WC5 process finished
# PRODUCT 2808 of family F1: Waiting for the machine WC6 to become available
# PRODUCT 2751 of family F2: Machine WC5 ready
# PRODUCT 2751 of family F2: starting to be processed by the machine WC5
# PRODUCT 2743 of family F2: Machine WC6 process finished
# PRODUCT 2760 of family F3: Machine WC6 ready
# PRODUCT 2760 of family F3: starting to be processed by the machine WC6
# PRODUCT 2837 of family F2: Waiting for the machine WC1 to become available
# PRODUCT 2760 of family F3: Machine WC6 process finished
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
